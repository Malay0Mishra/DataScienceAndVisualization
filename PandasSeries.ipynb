# %%
import pandas as pd

# %%
#SECTION_A
#Ques-1
ser1 = pd.Series([120,150,180,210])

# %%
#Ques-2
marks = pd.Series([72, 81, 69, 90])
marks.values
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Ques-3
marks.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Ques-4
temperatures = pd.Series([28,31,30,29], index=['Mon' , 'Tues', 'Wed' , 'Thu'])

# %%
#Ques-5
population = pd.Series([35, 42, 31], index=['Delhi','Mumbai','Jaipur'])
population['Jaipur']
# Out:
# np.int64(31)

# %%
#Ques-6
score = pd.Series([35, 68, 44, 79, 52])
score[score > 50]
# Out:
# 1    68
# 3    79
# 4    52
# dtype: int64

# %%
#Ques-7
subjects = pd.Series([76, 83, 91], index=['Physics','Chemistry','Maths'])
'Chemistry' in subjects.index
# Out:
# True

# %%
#Ques-8
s1 = series.todict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_616/333867583.py in <cell line: 0>()
#       1 #Ques-8
# ----> 2 s = pd.Series(data)
#
# NameError: name 'data' is not defined

# %%
#Ques-9
prices = {'Pen': 10, 'Notebook': 55, 'Bag': 700}
price_series = pd.Series(prices)

# %%
#Ques-10
#Dictonaries keys

# %%
#Ques-11
#D will return NaN

# %%
#Ques-12
s = pd.Series({'a': 10, 'b': 20, 'c': 30},
              index=['a', 'b', 'c', 'd'])

s.isnull()
# Out:
# a    False
# b    False
# c    False
# d     True
# dtype: bool

# %%
#Ques-13
s.notnull()
# Out:
# a     True
# b     True
# c     True
# d    False
# dtype: bool

# %%
#Ques-14
# sales.name = "Monthly_Sales"

# %%
#Ques-15
# sales.index.name = "Months"

# %%
########################################### SECTION B ################################################

# %%
#Ques-16
s = pd.Series([18, 45, 27, 61], index=['P','Q','R','S'])
s[s > 30]
# Out:
# Q    45
# S    61
# dtype: int64

# %%
#Ques-17
s = pd.Series([500, 600, 700], index=['East','West','North'])
'West' in s
500 in s
# Out:
# False

# %%
#Ques-18
city_data = {'Delhi': 80, 'Pune': 65, 'Kochi': 70}
series1 = pd.Series(city_data, index = ['Delhi' , 'Kochi' , 'Pune' , 'Chennai'])
series1
type(city_data)
# Out:
# dict

# %%
#Ques-19
s = pd.Series({'W': 5, 'X': 10, 'Y': 15}, index=['W','X','Y','Z'])
s.notnull()
# Out:
# W     True
# X     True
# Y     True
# Z    False
# dtype: bool

# %%
#Ques-20
# Same as Ques 19

# %%
#Ques-21
s1 = pd.Series([10, 20, 30], index=['A','B','C'])
s2 = pd.Series([1, 2, 3], index=['C','A','B'])
s1 + s2
# Out:
# A    12
# B    23
# C    31
# dtype: int64

# %%
#Ques-22
s1 = pd.Series({'A': 12, 'B': 18})
s2 = pd.Series({'B': 5, 'C': 9})
s1 + s2
# Out:
# A     NaN
# B    23.0
# C     NaN
# dtype: float64

# %%
#Ques-23
stock = pd.Series([25, 40, 18], index=['Item1','Item2','Item3'])
stock_dict = stock.to_dict()
stock2 = pd.Series(stock_dict)
stock2
# Out:
# Item1    25
# Item2    40
# Item3    18
# dtype: int64

# %%
#Ques-24
marks = {'Maths': 88, 'Science': 74, 'English': 69, 'History': 81}
marks1 = pd.Series(marks)
marks1[marks1 > 70]
# Out:
# Maths      88
# Science    74
# History    81
# dtype: int64

# %%
#Ques-25
# rev.name
# rev.index.name

# %%
############################################### SECTION D #########################################################

# %%
#Ques-26
north = pd.Series({'Jan': 40, 'Feb': 55, 'Mar': 60})
south = pd.Series({'Feb': 20, 'Mar': 25, 'Apr': 30})

total = north + south
total
# Out:
# Apr     NaN
# Feb    75.0
# Jan     NaN
# Mar    85.0
# dtype: float64

# %%
#Ques-27
d = {'Red': 12, 'Blue': 18, 'Green': 24}
labels = ['Green','Red','Yellow','Blue']
result = pd.Series(d, index=labels)
result
result.values
result.isnull()
# Out:
# Green     24.0
# Red       12.0
# Yellow     NaN
# Blue      18.0
# dtype: float64

# %%
#Ques-28
s = pd.Series([90, 75, 82], index=['Ravi','Aman','Neha'])
d = s.to_dict()
s2 = pd.Series(d)
#Everthing stays the Same

# %%
#Ques-29
sales = pd.Series(
    [10, 70, 50, 30],
    index=['Pen', 'Laptop', 'Bag', 'Book']
)

print(sales.values)
print(sales.index)

print(sales['Laptop'])

print(sales[sales > 500])

print('Bag' in sales.index)

sales_dict = sales.to_dict()
print(sales_dict)
# Out:
# [10 70 50 30]
# Index(['Pen', 'Laptop', 'Bag', 'Book'], dtype='object')
# 70
# Series([], dtype: int64)
# True
# {'Pen': 10, 'Laptop': 70, 'Bag': 50, 'Book': 30}

# %%
#Ques-30
data = {'A': 15, 'B': 35, 'C': 25}
s = pd.Series(data, index=['C','A','D','B'])
s.name = 'Observations'
s.index.name = 'Category'
#ORDER OF S will be same as series index
# D will have Null value
#Values greater than 20
#True for everthing and False for D
#as changed
